# %% [markdown]
# # **Canada Rural and Francophone Community Immigration pilots (RCIP)**

# %% [markdown]
# https://www.canada.ca/en/immigration-refugees-citizenship/news/2025/01/canada-launches-rural-and-francophone-community-immigration-pilots.html

# %% [markdown]
# The Francophone Immigration Pilot Program offers the opportunity to obtain permanent residence (PR) for skilled workers who wish to settle and work in rural and remote communities.
#
# As part of its implementation, 18 communities were selected based on their ability to support and benefit from skilled migrants. In this context, these communities have enabled certain employers to hire foreign talent to fill positions that could not be staffed with local workers.
#
# This application illustrates the location of each of the Program's communities. This work is developed with the purpose of allowing those interested in the Program to know the location of the Program's communities.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This application marks the geographic position of all the communities that will participate in the RCIP on a map. It also marks the position of the main cities of Canada, so that the proximity of each community to the nearest city can be distinguished.

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# #### Generating Maps with Python

# %%
## Task 1: Mark all launch sites on a map
Mark_map = folium.Map(location=[28.562302	, -80.577356], zoom_start=5)
Mark_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8a5b62c4e69676449543d5cd7c5d08f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8a5b62c4e69676449543d5cd7c5d08f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8a5b62c4e69676449543d5cd7c5d08f = L.map(
#                 &quot;map_c8a5b62c4e69676449543d5cd7c5d08f&quot;,
#                 {
#                     center: [28.562302, -80.577356],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66d7f2b80c4e5a9a7bcd6bc910c45ad1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66d7f2b80c4e5a9a7bcd6bc910c45ad1.addTo(map_c8a5b62c4e69676449543d5cd7c5d08f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# First, let's start by adding each site's location to a map using its latitude and longitude coordinates.

# %% [markdown]
# We have an augmented dataset named provincias.csv, which includes the latitude and longitude for each site.

# %%
# Download and read the `provincias.csv`
#await download(filename, "provincias.csv")
df = pd.read_csv("provincias.csv" , sep=';' ,encoding='ANSI')

# %% [markdown]
# Now, we can take a look at the coordinates for each site and analyze their locations.

# %%
df
# Out:
#      Minority                       Community   longitud     latitud
# 0       Rural           Comte de Pictou (N-E)  45.586072  -62.926039
# 1       Rural                 North Bay (Ont)  46.411582  -79.365500
# 2       Rural                   Sudbury (Ont)  46.717325  -81.080676
# 3       Rural                   Timmins (Ont)  48.552316  -81.051223
# 4       Rural           Sault Ste Marie (Ont)  46.576598  -84.299177
# ..        ...                             ...        ...         ...
# 57  reference                      Barrie  ON  44.389355  -79.690331
# 58  reference                    Whistler  BC  50.116322 -122.957359
# 59  reference  Detour Gold Lake Mine  Ontario  50.019459  -79.716560
# 60  reference                   Kitchener  ON  43.452969  -80.495064
# 61  reference                     Toronto  ON  43.642567  -79.387054
#
# [62 rows x 4 columns]

# %% [markdown]
# Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial Quebec City, Canada.

# %%
# Start location is quebec City
City_reference = [ 46.89656538835651, -71.36281624416118]
site_map = folium.Map(location = City_reference, zoom_start=10)

site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c617cbbeab6ec0f941de558a53d7f914 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c617cbbeab6ec0f941de558a53d7f914&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c617cbbeab6ec0f941de558a53d7f914 = L.map(
#                 &quot;map_c617cbbeab6ec0f941de558a53d7f914&quot;,
#                 {
#                     center: [46.89656538835651, -71.36281624416118],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_632a4dc76f78634381f108e10a08720e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_632a4dc76f78634381f108e10a08720e.addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
# Create a blue circle at Reference City's coordinate with a popup label showing its name
y = 'QUEBEC CITY'
circle = folium.Circle(City_reference, radius=1000, color='blue', fill=True).add_child(folium.Popup('Reference City'))

# Create a blue circle at Reference City's coordinate with a icon showing its name
marker = folium.map.Marker(
    City_reference,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#1b34a6;"><b>%s</b></div>' % y,
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c617cbbeab6ec0f941de558a53d7f914 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c617cbbeab6ec0f941de558a53d7f914&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c617cbbeab6ec0f941de558a53d7f914 = L.map(
#                 &quot;map_c617cbbeab6ec0f941de558a53d7f914&quot;,
#                 {
#                     center: [46.89656538835651, -71.36281624416118],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_632a4dc76f78634381f108e10a08720e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_632a4dc76f78634381f108e10a08720e.addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#             tile_layer_632a4dc76f78634381f108e10a08720e.addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#             var circle_8e53f39b941a1315ceec29bddf37dc0f = L.circle(
#                 [46.89656538835651, -71.36281624416118],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#         var popup_f7fbc1e64c2123dc6e69726270e98749 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f928184857590489d505303fec373a89 = $(`&lt;div id=&quot;html_f928184857590489d505303fec373a89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Reference City&lt;/div&gt;`)[0];
#                 popup_f7fbc1e64c2123dc6e69726270e98749.setContent(html_f928184857590489d505303fec373a89);
#
#
#
#         circle_8e53f39b941a1315ceec29bddf37dc0f.bindPopup(popup_f7fbc1e64c2123dc6e69726270e98749)
#         ;
#
#
#
#
#             var marker_4f86532e63f85f24a59088e9d5b0713e = L.marker(
#                 [46.89656538835651, -71.36281624416118],
#                 {
# }
#             ).addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#             var div_icon_cce831d796b0e96119fb9ddf4441e6f3 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#1b34a6;\&quot;\u003e\u003cb\u003eQUEBEC CITY\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_4f86532e63f85f24a59088e9d5b0713e.setIcon(div_icon_cce831d796b0e96119fb9ddf4441e6f3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Task 2: Mark the communities for each site on the map

# %%
# Start location each community
coord = [df.iat[0,2] , df.iat[0,3] ]
coord
type(coord)
comunity = df.iat[0,1]
comunity
# Out:
# 'Comte de Pictou (N-E)'

# %%
df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Minority   62 non-null     object
#  1   Community  62 non-null     object
#  2   longitud   62 non-null     float64
#  3   latitud    62 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 2.1+ KB

# %%
# Apply a function to check the value of `class` column
# If Minority=1, community_color value will be green
# If Minority=0, community_color value will be red

# Function to assign color to launch outcome
def assign_marker_color(community):
    if community == 'Rural':
        return 'green'
    elif community == 'Francophone':
            return 'red'
    else:
        return 'blue'
    
df['Community_color'] = df['Minority'].apply(assign_marker_color)
df.tail(-1)
# Out:
#      Minority                       Community   longitud     latitud  \
# 1       Rural                 North Bay (Ont)  46.411582  -79.365500
# 2       Rural                   Sudbury (Ont)  46.717325  -81.080676
# 3       Rural                   Timmins (Ont)  48.552316  -81.051223
# 4       Rural           Sault Ste Marie (Ont)  46.576598  -84.299177
# 5       Rural               Thunder Bay (Ont)  48.499564  -89.201043
# ..        ...                             ...        ...         ...
# 57  reference                      Barrie  ON  44.389355  -79.690331
# 58  reference                    Whistler  BC  50.116322 -122.957359
# 59  reference  Detour Gold Lake Mine  Ontario  50.019459  -79.716560
# 60  reference                   Kitchener  ON  43.452969  -80.495064
# 61  reference                     Toronto  ON  43.642567  -79.387054
#
#    Community_color
# 1            green
# 2            green
# 3            green
# 4            green
# 5            green
# ..             ...
# 57            blue
# 58            blue
# 59            blue
# 60            blue
# 61            blue
#
# [61 rows x 5 columns]

# %% [markdown]
# Create a new column in `df` dataframe called `community_color` to store the marker colors based on the `Minority` value

# %%
# Communities location
for i in range(0,len(df['Community_color'])):
    comunity = df.iat[i,1]
    coord = [df.iat[i,2] , df.iat[i,3] ]

#for index, row in df.iterrows():
#    comunity = row['Community']
#    coord = [row['latitud'] , row['longitud' ]]
    
    #site_map = folium.Map(location = coord, zoom_start=10)

    # Create a blue circle at Reference City's coordinate with a popup label showing its name
    circle = folium.Circle(location = coord, radius=10000, color=df.iat[i,4] , fill=True).add_child(folium.Popup(comunity))

    # Create a blue circle at Reference City's coordinate with a icon showing its name
    marker = folium.map.Marker(
        coord,
        # Create an icon as a text label
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html = '<div style="font-size: 12; color:#0f0f0f;"><b>%s</b></div>' % comunity,
            )
        )
    site_map.add_child(circle)
    site_map.add_child(marker)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c617cbbeab6ec0f941de558a53d7f914 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c617cbbeab6ec0f941de558a53d7f914&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c617cbbeab6ec0f941de558a53d7f914 = L.map(
#                 &quot;map_c617cbbeab6ec0f941de558a53d7f914&quot;,
#                 {
#                     center: [46.89656538835651, -71.36281624416118],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_632a4dc76f78634381f108e10a08720e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_632a4dc76f78634381f108e10a08720e.addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#             tile_layer_632a4dc76f78634381f108e10a08720e.addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#             var circle_8e53f39b941a1315ceec29bddf37dc0f = L.circle(
#                 [46.89656538835651, -71.36281624416118],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#         var popup_f7fbc1e64c2123dc6e69726270e98749 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f928184857590489d505303fec373a89 = $(`&lt;div id=&quot;html_f928184857590489d505303fec373a89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Reference City&lt;/div&gt;`)[0];
#                 popup_f7fbc1e64c2123dc6e69726270e98749.setContent(html_f928184857590489d505303fec373a89);
#
#
#
#         circle_8e53f39b941a1315ceec29bddf37dc0f.bindPopup(popup_f7fbc1e64c2123dc6e69726270e98749)
#         ;
#
#
#
#
#             var marker_4f86532e63f85f24a59088e9d5b0713e = L.marker(
#                 [46.89656538835651, -71.36281624416118],
#                 {
# }
#             ).addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#             var div_icon_cce831d796b0e96119fb9ddf4441e6f3 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#1b34a6;\&quot;\u003e\u003cb\u003eQUEBEC CITY\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_4f86532e63f85f24a59088e9d5b0713e.setIcon(div_icon_cce831d796b0e96119fb9ddf4441e6f3);
#
#
#             tile_layer_632a4dc76f78634381f108e10a08720e.addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#             var circle_76ff1bbb7ab637e7775d941107b2800f = L.circle(
#                 [45.58607237, -62.92603905],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#         var popup_80090d01dd1bf499d301ad0412c762c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48264fac2d0e4a7d1e817975dbee2404 = $(`&lt;div id=&quot;html_48264fac2d0e4a7d1e817975dbee2404&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Comte de Pictou (N-E)&lt;/div&gt;`)[0];
#                 popup_80090d01dd1bf499d301ad0412c762c1.setContent(html_48264fac2d0e4a7d1e817975dbee2404);
#
#
#
#         circle_76ff1bbb7ab637e7775d941107b2800f.bindPopup(popup_80090d01dd1bf499d301ad0412c762c1)
#         ;
#
#
#
#
#             var marker_5f61b38f590d4e12e646adb6f7a21eac = L.marker(
#                 [45.58607237, -62.92603905],
#                 {
# }
#             ).addTo(map_c617cbbeab6ec0f941de558a53d7f914);
#
#
#             var div_icon_3bd4710a985058b25baf9e08f40fe391 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#0f0f0f;\&quot;\u003e\u003cb\u003eComte de Pictou (N-E)\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_5f61b38f590d4e12e646adb6f7a21eac.setIcon(div_icon_3bd4710a985058b25baf9e08f40fe

# %% [markdown]
# # Notes:
# https://www.google.com/search?q=color+%23d35400&rlz=1C1CHZN_enCO1069CO1069&oq=color+%23d35400&gs_lcrp=EgZjaHJvbWUyBggAEEUYOTIICAEQABgWGB4yCggCEAAYgAQYogQyBwgDEAAY7wUyBwgEEAAY7wUyBggFEEUYPDIGCAYQRRg8MgYIBxBFGDzSAQkyNjI0ajBqMTWoAgiwAgE&sourceid=chrome&ie=UTF-8

# %% [markdown]
# ## Authors

# %% [markdown]
# [Liliana Mendoza](https://www.linkedin.com/in/liliana-adriana-mendoza-saboya/)

# %% [markdown]
# <!--## Change Log--!>

# %% [markdown]
# <!--| Date (YYYY-MM-DD) | Version | Changed By      | Change Description      |
# | ----------------- | ------- | -------------   | ----------------------- |
# | 2022-11-09        | 1.0     | Pratiksha Verma | Converted initial version to Jupyterlite|--!>

# %% [markdown]
# ### <h3 align="center"> IBM Corporation 2022. All rights reserved. <h3/>
